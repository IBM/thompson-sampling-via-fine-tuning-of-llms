# %%
import torch

# Load the file
file_path = "../tosfit/results/?.pt"
data = torch.load(file_path)

# Check if 'config' is in the dictionary
config_entry = data.get("config", "Key 'config' not found.")

config_entry
